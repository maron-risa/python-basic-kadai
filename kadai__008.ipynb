# %%
var = 15

if var % 3 == 0 and var % 5 != 0:
  print("Fizz")
elif var % 5 == 0 and var % 3 != 0:
  print("Buzz")
elif var % 3 == 0 and var % 5 == 0:
  print("FizzBuss")
else:
  print(var)
# Out:
# FizzBuss
