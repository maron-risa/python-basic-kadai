# %%
list = ["水","金","地","火","木","土","天","海","冥"]

index = 0

for planet in list:
  print(planet)

index = -1

while index < 8:
  index = index +1
  print(list[index])
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
