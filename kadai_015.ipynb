# %%
class Human:
  def __init__(self, name, age):
      self.name = name
      self.age = age

  def printinfo(self):
      print(self.name)
      print(self.age)

a001 = Human("tanaka", "33")
a001.printinfo()
# Out:
# tanaka
# 33
