# %%
purchased = True

def is_purchased():
  if (purchased):
    return True
  else:
    return False

def add_two_arguments(price, tax):
  tax = price * 0.1
  total = price + tax
  if (is_purchased()):
    return total


add_two_arguments(200, 5)
# Out:
# 220.0
